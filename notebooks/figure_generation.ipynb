# %% [markdown]
# # Figure Generation for Paper
#
# This notebook generates publication-quality figures for the paper.

# %%
import sys
sys.path.append('../src')

import pickle
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from pathlib import Path
from utils.config import ExperimentConfig
from analysis.visualization import (
    plot_learning_curves,
    plot_smoothness_comparison,
    plot_two_stage_results,
    plot_frequency_spectra,
    plot_progressive_corruption
)

# %matplotlib inline
sns.set_style('whitegrid')

# Create figures directory
ExperimentConfig.create_directories()
figures_dir = ExperimentConfig.FIGURES_DIR
print(f"Figures will be saved to: {figures_dir}")

# %% [markdown]
# ## Generate All Figures
#
# This notebook will generate all publication-quality figures for the paper.
